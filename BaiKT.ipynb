# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# MSSV: 2174802010886
# Ten: Vo Quoc Thanh

# %%
#1
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace", "Hannah", "Ivan", "Jack", "Kelly", "Liam", "Mona", "Nina", "Oscar"],
    "Age": [25, 30, 35, 28, 22, 45, 34, 31, 27, 29, 33, 40, 26, 32, 36],
    "Salary": [50000, 60000, 70000, 55000, 52000, 80000, 72000, 68000, 61000, 59000, 63000, 77000, 53000, 66000, 75000]
}

# %%
df = pd.DataFrame(data)

# %%
#Cau2
df.head()
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000
# 3    David   28   55000
# 4      Eva   22   52000

# %%
#Cau3
dfloc = df[df['Age'] > 28]
print(dfloc)
# Out:
#        Name  Age  Salary
# 1       Bob   30   60000
# 2   Charlie   35   70000
# 5     Frank   45   80000
# 6     Grace   34   72000
# 7    Hannah   31   68000
# 9      Jack   29   59000
# 10    Kelly   33   63000
# 11     Liam   40   77000
# 13     Nina   32   66000
# 14    Oscar   36   75000

# %%
#Cau4
salary = df['Salary'].mean()
print(salary)
# Out:
# 64066.666666666664

# %%
#Cau5
groupy = df.groupby('Age')['Salary'].sum()
print(groupy)
# Out:
# Age
# 22    52000
# 25    50000
# 26    53000
# 27    61000
# 28    55000
# 29    59000
# 30    60000
# 31    68000
# 32    66000
# 33    63000
# 34    72000
# 35    70000
# 36    75000
# 40    77000
# 45    80000
# Name: Salary, dtype: int64

# %%
#Cau 6
sort = df.sort_values(by='Salary', ascending=False)
print(sort)
# Out:
#        Name  Age  Salary
# 5     Frank   45   80000
# 11     Liam   40   77000
# 14    Oscar   36   75000
# 6     Grace   34   72000
# 2   Charlie   35   70000
# 7    Hannah   31   68000
# 13     Nina   32   66000
# 10    Kelly   33   63000
# 8      Ivan   27   61000
# 1       Bob   30   60000
# 9      Jack   29   59000
# 3     David   28   55000
# 12     Mona   26   53000
# 4       Eva   22   52000
# 0     Alice   25   50000

# %%
#Cau 7


plt.figure()
plt.hist(df['Age'], bins=range(df['Age'].min(), df['Age'].max() + 1), edgecolor='black')
plt.xlabel
plt.ylabel
plt.grid(True)
plt.show()

# %%
#Cau 8

plt.figure()
df['Salary'].plot(kind='line')
plt.title('Biểu đồ đường Salary')
plt.xlabel('Index')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %%
#Cau 9
plt.figure()
df['Age'].value_counts().plot(kind='pie')
plt.title('Biểu đồ tròn Age')
plt.ylabel('')
plt.show()

# %%
#Cau 10
plt.figure()
plt.scatter(df['Age'], df['Salary'])
plt.title('Biểu đồ phân tán Age & Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %%
#Cau 11
nan_exists = df.isna().any().any()
print(nan_exists)
# Out:
# False

# %%
#Cau 12
mean_age = df['Age'].mean()
df.loc[df['Age'] > 30, 'Age'] = mean_age
df.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16916\1207616474.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '31.533333333333335' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Age'] > 30, 'Age'] = mean_age
#       Name        Age  Salary
# 0    Alice  25.000000   50000
# 1      Bob  30.000000   60000
# 2  Charlie  31.533333   70000
# 3    David  28.000000   55000
# 4      Eva  22.000000   52000

# %%
#Cau 13
df['Age_normalized'] = (df['Age'] - df['Age'].min()) / (df['Age'].max() - df['Age'].min())
df.head()
# Out:
#       Name        Age  Salary  Age_normalized
# 0    Alice  25.000000   50000        0.314685
# 1      Bob  30.000000   60000        0.839161
# 2  Charlie  31.533333   70000        1.000000
# 3    David  28.000000   55000        0.629371
# 4      Eva  22.000000   52000        0.000000

# %%
#Cau 14
def Tuoi(age):
    if age < 30:
        return 'Young'
    elif age <= 60:
        return 'Middle-aged'
    else:
        return 'Old'

df['Age_group'] = df['Age'].apply(Tuoi)
df.head()
# Out:
#       Name        Age  Salary  Age_normalized    Age_group
# 0    Alice  25.000000   50000        0.314685        Young
# 1      Bob  30.000000   60000        0.839161  Middle-aged
# 2  Charlie  31.533333   70000        1.000000  Middle-aged
# 3    David  28.000000   55000        0.629371        Young
# 4      Eva  22.000000   52000        0.000000        Young

# %%
#Cau 15
df['Salary_pct_change'] = df['Salary'].pct_change()
df.head()
# Out:
#       Name        Age  Salary  Age_normalized    Age_group  Salary_pct_change
# 0    Alice  25.000000   50000        0.314685        Young                NaN
# 1      Bob  30.000000   60000        0.839161  Middle-aged           0.200000
# 2  Charlie  31.533333   70000        1.000000  Middle-aged           0.166667
# 3    David  28.000000   55000        0.629371        Young          -0.214286
# 4      Eva  22.000000   52000        0.000000        Young          -0.054545

# %%
#Cau 16
df_deduped = df.drop_duplicates(subset='Name', keep='first')
df.head
# Out:
# <bound method NDFrame.head of        Name        Age  Salary  Age_normalized    Age_group  Salary_pct_change
# 0     Alice  25.000000   50000        0.314685        Young                NaN
# 1       Bob  30.000000   60000        0.839161  Middle-aged           0.200000
# 2   Charlie  31.533333   70000        1.000000  Middle-aged           0.166667
# 3     David  28.000000   55000        0.629371        Young          -0.214286
# 4       Eva  22.000000   52000        0.000000        Young          -0.054545
# 5     Frank  31.533333   80000        1.000000  Middle-aged           0.538462
# 6     Grace  31.533333   72000        1.000000  Middle-aged          -0.100000
# 7    Hannah  31.533333   68000        1.000000  Middle-aged          -0.055556
# 8      Ivan  27.000000   61000        0.524476        Young          -0.102941
# 9      Jack  29.000000   59000        0.734266        Young          -0.032787
# ...

# %%
#Cau 17

df.to_csv('KT.csv', index = False)
